# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder
import os
import pygame

# logging
log_dir = "./logs/"
video_dir = "./logs/videos/"
os.makedirs(log_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# seed
SEED = 42
np.random.seed(SEED)

# create : pendulum environment
def make_env():
    env = gym.make("LunarLanderContinuous-v3", render_mode="rgb_array")
    env = Monitor(env, filename=os.path.join(log_dir, "monitor.csv"))
    return env

train_env = DummyVecEnv([make_env])
train_env = VecVideoRecorder(
    train_env,
    video_folder=video_dir,
    record_video_trigger=lambda step: step % 30000 == 0,
    video_length=10000,
    name_prefix="train_lander"
)

# get the number of actions
n_actions = train_env.action_space.shape[0]

# adding action noise
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# Create a TD3 agent
model = TD3(
    "MlpPolicy",  # MLP -> Multi Layer Perceptron
    train_env,    # The environment
    action_noise=action_noise,
    verbose=1,
    seed=SEED,
    learning_rate=0.001,     
    buffer_size=100000,      
    batch_size=100,          
    learning_starts=1000,    
    policy_delay=2,          
    target_policy_noise=0.2,
    target_noise_clip=0.5,
    tau=0.005,              
    gamma=0.99,
)

model.learn(total_timesteps=100000)
model.save("td3_lander")
train_env.close()

# create : test environment
test_env = DummyVecEnv([make_env])
test_env = VecVideoRecorder(
    test_env,
    video_folder=video_dir,
    record_video_trigger=lambda step: step == 0,
    video_length=600,
    name_prefix="test_lander"
)

# evaluate : agent
obs = test_env.reset()
total_reward = 0

for _ in range(200):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = test_env.step(action)
    total_reward += reward
    if done[0]:
        break

print(f"Evaluation reward: {total_reward[0]:.2f}")
test_env.close()

# GUI
gui_env = gym.make("LunarLanderContinuous-v3", render_mode="human")
obs, _ = gui_env.reset(seed=SEED)
total_reward = 0

for _ in range(1000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, _ = gui_env.step(action)
    total_reward += reward
    if terminated or truncated:
        break

print(f"GUI Evaluation reward: {total_reward:.2f}")
gui_env.close()
pygame.quit()
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -222     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 1005     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 483      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -179     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 1033     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 899      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 157      |
# |    ep_rew_mean     | -294     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 491      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1883     |
# | train/             |          |
# |    actor_loss      | 2.4      |
# |    critic_loss     | 4.83     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 882      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 151      |
# |    ep_rew_mean     | -272     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 435      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2412     |
# | train/             |          |
# |    actor_loss      | 4.35     |
# |    critic_loss     | 17.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1411     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 160      |
# |    ep_rew_mean     | -342     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 397      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 3206     |
# | train/             |          |
# |    actor_loss      | 4.14     |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2205     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 176      |
# |    ep_rew_mean     | -309     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 373      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 4213     |
# | train/             |          |
# |    actor_loss      | 3.45     |
# |    critic_loss     | 6.74     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3212     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | -267     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 357      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 5444     |
# | train/             |          |
# |    actor_loss      | 6.98     |
# |    critic_loss     | 24.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4443     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 273      |
# |    ep_rew_mean     | -268     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 339      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 8725     |
# | train/             |          |
# |    actor_loss      | 4.53     |
# |    critic_loss     | 6.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7724     |
# ---------------------------------
# Saving video to /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-0-to-step-10000.mp4
# MoviePy - Building video /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-0-to-step-10000.mp4.
# MoviePy - Writing video /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-0-to-step-10000.mp4
# MoviePy - Done !
# MoviePy - video ready /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-0-to-step-10000.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 353      |
# |    ep_rew_mean     | -243     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 246      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 12725    |
# | train/             |          |
# |    actor_loss      | 4.93     |
# |    critic_loss     | 4.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11724    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 409      |
# |    ep_rew_mean     | -230     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 240      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 16352    |
# | train/             |          |
# |    actor_loss      | 4.86     |
# |    critic_loss     | 7.03     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15351    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 436      |
# |    ep_rew_mean     | -210     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 237      |
# |    time_elapsed    | 80       |
# |    total_timesteps | 19206    |
# | train/             |          |
# |    actor_loss      | 6.49     |
# |    critic_loss     | 7.31     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 18205    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 446      |
# |    ep_rew_mean     | -196     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 235      |
# |    time_elapsed    | 90       |
# |    total_timesteps | 21395    |
# | train/             |          |
# |    actor_loss      | 2.5      |
# |    critic_loss     | 8.58     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20394    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 470      |
# |    ep_rew_mean     | -189     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 234      |
# |    time_elapsed    | 104      |
# |    total_timesteps | 24429    |
# | train/             |          |
# |    actor_loss      | -0.85    |
# |    critic_loss     | 3.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 468      |
# |    ep_rew_mean     | -186     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 234      |
# |    time_elapsed    | 111      |
# |    total_timesteps | 26212    |
# | train/             |          |
# |    actor_loss      | 4.75     |
# |    critic_loss     | 8.75     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25211    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 458      |
# |    ep_rew_mean     | -184     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 234      |
# |    time_elapsed    | 117      |
# |    total_timesteps | 27497    |
# | train/             |          |
# |    actor_loss      | -1.65    |
# |    critic_loss     | 23.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26496    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 459      |
# |    ep_rew_mean     | -176     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 234      |
# |    time_elapsed    | 125      |
# |    total_timesteps | 29394    |
# | train/             |          |
# |    actor_loss      | 4.39     |
# |    critic_loss     | 7.24     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28393    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 452      |
# |    ep_rew_mean     | -172     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 236      |
# |    time_elapsed    | 130      |
# |    total_timesteps | 30752    |
# | train/             |          |
# |    actor_loss      | 1.99     |
# |    critic_loss     | 7.8      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29751    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 454      |
# |    ep_rew_mean     | -166     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 239      |
# |    time_elapsed    | 136      |
# |    total_timesteps | 32672    |
# | train/             |          |
# |    actor_loss      | 2.27     |
# |    critic_loss     | 12.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31671    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 467      |
# |    ep_rew_mean     | -160     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 244      |
# |    time_elapsed    | 145      |
# |    total_timesteps | 35485    |
# | train/             |          |
# |    actor_loss      | -0.303   |
# |    critic_loss     | 36.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 34484    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 492      |
# |    ep_rew_mean     | -156     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 249      |
# |    time_elapsed    | 157      |
# |    total_timesteps | 39338    |
# | train/             |          |
# |    actor_loss      | -3.06    |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 38337    |
# ---------------------------------
# Saving video to /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-30000-to-step-40000.mp4
# MoviePy - Building video /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-30000-to-step-40000.mp4.
# MoviePy - Writing video /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-30000-to-step-40000.mp4
# MoviePy - Done !
# MoviePy - video ready /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-30000-to-step-40000.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 503      |
# |    ep_rew_mean     | -147     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 233      |
# |    time_elapsed    | 180      |
# |    total_timesteps | 42256    |
# | train/             |          |
# |    actor_loss      | 2.4      |
# |    critic_loss     | 17.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 41255    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 510      |
# |    ep_rew_mean     | -140     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 231      |
# |    time_elapsed    | 193      |
# |    total_timesteps | 44906    |
# | train/             |          |
# |    actor_loss      | 0.624    |
# |    critic_loss     | 9.6      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43905    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 514      |
# |    ep_rew_mean     | -138     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 230      |
# |    time_elapsed    | 205      |
# |    total_timesteps | 47270    |
# | train/             |          |
# |    actor_loss      | 1.92     |
# |    critic_loss     | 3.46     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 46269    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 515      |
# |    ep_rew_mean     | -133     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 230      |
# |    time_elapsed    | 214      |
# |    total_timesteps | 49424    |
# | train/             |          |
# |    actor_loss      | -0.114   |
# |    critic_loss     | 18.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 48423    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 525      |
# |    ep_rew_mean     | -130     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 226      |
# |    time_elapsed    | 232      |
# |    total_timesteps | 52531    |
# | train/             |          |
# |    actor_loss      | -1.93    |
# |    critic_loss     | 7.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 51530    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 542      |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 225      |
# |    time_elapsed    | 242      |
# |    total_timesteps | 54676    |
# | train/             |          |
# |    actor_loss      | -1.61    |
# |    critic_loss     | 4.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 53675    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 574      |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 223      |
# |    time_elapsed    | 260      |
# |    total_timesteps | 58315    |
# | train/             |          |
# |    actor_loss      | -0.923   |
# |    critic_loss     | 2.83     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 57314    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 582      |
# |    ep_rew_mean     | -75.6    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 223      |
# |    time_elapsed    | 268      |
# |    total_timesteps | 60099    |
# | train/             |          |
# |    actor_loss      | -2.59    |
# |    critic_loss     | 37.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59098    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 599      |
# |    ep_rew_mean     | -60.1    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 225      |
# |    time_elapsed    | 275      |
# |    total_timesteps | 62277    |
# | train/             |          |
# |    actor_loss      | -1.63    |
# |    critic_loss     | 8        |
# |    learning_rate   | 0.001    |
# |    n_updates       | 61276    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 612      |
# |    ep_rew_mean     | -30.8    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 227      |
# |    time_elapsed    | 282      |
# |    total_timesteps | 64433    |
# | train/             |          |
# |    actor_loss      | -5.43    |
# |    critic_loss     | 9.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 63432    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 612      |
# |    ep_rew_mean     | -19.8    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 228      |
# |    time_elapsed    | 285      |
# |    total_timesteps | 65453    |
# | train/             |          |
# |    actor_loss      | -0.766   |
# |    critic_loss     | 6.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 64452    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 611      |
# |    ep_rew_mean     | -8.82    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 229      |
# |    time_elapsed    | 289      |
# |    total_timesteps | 66586    |
# | train/             |          |
# |    actor_loss      | -3.2     |
# |    critic_loss     | 5.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 65585    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 601      |
# |    ep_rew_mean     | 6.31     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 231      |
# |    time_elapsed    | 296      |
# |    total_timesteps | 68864    |
# | train/             |          |
# |    actor_loss      | -6.82    |
# |    critic_loss     | 5.24     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 67863    |
# ---------------------------------
# Saving video to /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-60000-to-step-70000.mp4
# MoviePy - Building video /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-60000-to-step-70000.mp4.
# MoviePy - Writing video /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-60000-to-step-70000.mp4
# MoviePy - Done !
# MoviePy - video ready /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-60000-to-step-70000.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 574      |
# |    ep_rew_mean     | 10.4     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 225      |
# |    time_elapsed    | 311      |
# |    total_timesteps | 70153    |
# | train/             |          |
# |    actor_loss      | -5.52    |
# |    critic_loss     | 4.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 69152    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 546      |
# |    ep_rew_mean     | 22.6     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 226      |
# |    time_elapsed    | 313      |
# |    total_timesteps | 70985    |
# | train/             |          |
# |    actor_loss      | -7.88    |
# |    critic_loss     | 15.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 69984    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 541      |
# |    ep_rew_mean     | 25.8     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 227      |
# |    time_elapsed    | 322      |
# |    total_timesteps | 73327    |
# | train/             |          |
# |    actor_loss      | -13.9    |
# |    critic_loss     | 29.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 72326    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 534      |
# |    ep_rew_mean     | 27.5     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 227      |
# |    time_elapsed    | 328      |
# |    total_timesteps | 74818    |
# | train/             |          |
# |    actor_loss      | -8.41    |
# |    critic_loss     | 8.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 73817    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 512      |
# |    ep_rew_mean     | 29.3     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 228      |
# |    time_elapsed    | 331      |
# |    total_timesteps | 75601    |
# | train/             |          |
# |    actor_loss      | -20.1    |
# |    critic_loss     | 15.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 74600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 512      |
# |    ep_rew_mean     | 42.3     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 229      |
# |    time_elapsed    | 337      |
# |    total_timesteps | 77409    |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 320      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 76408    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 518      |
# |    ep_rew_mean     | 56.7     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 230      |
# |    time_elapsed    | 344      |
# |    total_timesteps | 79280    |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 18.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78279    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 506      |
# |    ep_rew_mean     | 55       |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 230      |
# |    time_elapsed    | 346      |
# |    total_timesteps | 79969    |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 12.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78968    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | 62.9     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 231      |
# |    time_elapsed    | 348      |
# |    total_timesteps | 80614    |
# | train/             |          |
# |    actor_loss      | -9.28    |
# |    critic_loss     | 44.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79613    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 490      |
# |    ep_rew_mean     | 70.7     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 232      |
# |    time_elapsed    | 351      |
# |    total_timesteps | 81662    |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 6.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80661    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 471      |
# |    ep_rew_mean     | 80.1     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 232      |
# |    time_elapsed    | 354      |
# |    total_timesteps | 82632    |
# | train/             |          |
# |    actor_loss      | -16.8    |
# |    critic_loss     | 6.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81631    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 451      |
# |    ep_rew_mean     | 87.2     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 233      |
# |    time_elapsed    | 361      |
# |    total_timesteps | 84477    |
# | train/             |          |
# |    actor_loss      | -9.66    |
# |    critic_loss     | 17.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83476    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 435      |
# |    ep_rew_mean     | 96.3     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 234      |
# |    time_elapsed    | 365      |
# |    total_timesteps | 85789    |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 12.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 84788    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 424      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 235      |
# |    time_elapsed    | 370      |
# |    total_timesteps | 87354    |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 8.69     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 86353    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 415      |
# |    ep_rew_mean     | 116      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 236      |
# |    time_elapsed    | 375      |
# |    total_timesteps | 88775    |
# | train/             |          |
# |    actor_loss      | -19.3    |
# |    critic_loss     | 5.58     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 87774    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 409      |
# |    ep_rew_mean     | 125      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 236      |
# |    time_elapsed    | 381      |
# |    total_timesteps | 90339    |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 10.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 89338    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 403      |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 238      |
# |    time_elapsed    | 389      |
# |    total_timesteps | 92868    |
# | train/             |          |
# |    actor_loss      | -19.3    |
# |    critic_loss     | 9.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 91867    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 398      |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 239      |
# |    time_elapsed    | 394      |
# |    total_timesteps | 94441    |
# | train/             |          |
# |    actor_loss      | -20.1    |
# |    critic_loss     | 51.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 93440    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 379      |
# |    ep_rew_mean     | 136      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 240      |
# |    time_elapsed    | 400      |
# |    total_timesteps | 96227    |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 9.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 95226    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 380      |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 241      |
# |    time_elapsed    | 406      |
# |    total_timesteps | 98075    |
# | train/             |          |
# |    actor_loss      | -21.9    |
# |    critic_loss     | 8.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97074    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 368      |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 241      |
# |    time_elapsed    | 409      |
# |    total_timesteps | 99069    |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 5.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98068    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 352      |
# |    ep_rew_mean     | 123      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 242      |
# |    time_elapsed    | 411      |
# |    total_timesteps | 99610    |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 5.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98609    |
# ---------------------------------
# Saving video to /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-90000-to-step-100000.mp4
# MoviePy - Building video /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-90000-to-step-100000.mp4.
# MoviePy - Writing video /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-90000-to-step-100000.mp4
# MoviePy - Done !
# MoviePy - video ready /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/train_lander-step-90000-to-step-100000.mp4
# Evaluation reward: 201.04
# MoviePy - Building video /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/test_lander-step-0-to-step-600.mp4.
# MoviePy - Writing video /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/test_lander-step-0-to-step-600.mp4
# MoviePy - Done !
# MoviePy - video ready /Users/mehulxyz/dev/lunarLander/lander_td3/logs/videos/test_lander-step-0-to-step-600.mp4
# GUI Evaluation reward: -15.44
